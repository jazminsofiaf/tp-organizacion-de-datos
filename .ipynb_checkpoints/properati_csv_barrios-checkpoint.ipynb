# %% [markdown]
# Hay propiedades que tienen como barrio capital federal, vamos a tratar de descubrir el barrio a través de la descripcion
# y guardarlo asi

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
from pandas import Series
# %matplotlib inline

# %%
import unicodedata
def eliminar_signos(text):
    return ''.join([i if ord(i) < 128 else ' ' for i in text])
def eliminar_tildes(s):
    return ''.join((c for c in unicodedata.normalize('NFD', s) if unicodedata.category(c) != 'Mn'))

def unificate_description(d):
    if(pd.notnull(d)):
        return eliminar_signos(eliminar_tildes(d).lower())
    return d

# %%
properati_filtered= pd.read_csv('../tp1/properati_filtered1.csv',encoding='UTF-8')

# %%
properati_filtered.description = properati_filtered.description.map(lambda d: unificate_description(d))

# %%
properati_filtered.description
# Out:
# 0        en exclusivaen muy linda casa, luminosa, en lo...
# 1        hermoso monoambiente en el condominio del hote...
# 2        local en venta a estrenar, planta baja 150 m2 ...
# 3        la propiedad cuenta con entrada exclusiva desd...
# 4        edificio de muy buena categoria emplazado sobr...
# 5        departamento de 3 ambientes con terraza a la v...
# 6        venta de departamento 3 ambientessup total: 55...
# 7        venta de departamento 3 ambientessup total: 55...
# 8        monoambiente en puerto madero.    consultar di...
# 9        se trata de un local comercial ubicado sobre c...
# 10       lindisima casa en la alamedala casa tiene piso...
# 11       monoambiente, amplio, luminoso, hall de recepc...
# 12       importante emprendimiento en pleno belgrano er...
# 13       venta de departamento 2 ambientes con renta y ...
# 14       venta de departamento monoambiente en san cris...
# 15       venta de departamento monoambiente en san cris...
# 16       venta de departamento 2 ambientes en barrio no...
# 17       venta de departamento monoambiente en san cris...
# 18       venta de departamento 2 ambientes con renta en...
# 19       venta de monoambiente con renta en nunez-descr...
# 20       venta de departamento 4 ambientes en belgrano-...
# 21       venta de departamento  en barrio norte-descrip...
# 22       localventa de local  en centro / microcentro-d...
# 23       localventa de local  en microcentro con renta-...
# 24       localventa de local  en boedo-descripcion:-exc...
# 25       venta de departamento monoambiente en san cris...
# 26       venta de departamento monoambiente en san cris...
# 27       venta de departamento monoambiente en san cris...
# 28       venta de monoambiente con renta en nunez-descr...
# 29       venta de departamento 2 ambientes con renta en...
#                                ...
# 78644    muy buen chalet, desarrollado en 2 plantas, 4 ...
# 78645    espectacular departamento de 3 dormitorios mas...
# 78646    muy linda casa en el barrio san rafael, sobre ...
# 78647    semipiso al frente de 3 ambientes, 2 banos, co...
# 78648    tigre, montevideo 1300 - excelente departament...
# 78649    muy lindo y luminoso departamento.muy buena ub...
# 78650    ruca inmuebles - 011-15- / 011- -  -  casa a e...
# 78651    departamento 96m, bs.as. g.b.a. zona norte, sa...
# 78652    casa sobre linea municipal, estar de recepcion...
# 78653    casa tipo cabana, la misma consta de living am...
# 78654    excelente e impecable casa en venta en las lom...
# 78655    edificio proceres | residencialamplio tres amb...
# 78656    departamento de 2 ambientes al frente,  en edi...
# 78657    alem propiedades |roberto celanooficina lomas ...
# 78658    edificio proceres | residencialamplio dos ambi...
# 78659    edificio proceres | residencialamplio dos ambi...
# 78660    edificio proceres | residencialamplio dos ambi...
# 78661    monoambiente al frente - consultar pisos dispo...
# 78662    monoambiente al frente - consultar pisos dispo...
# 78663    monoambiente al frente - consultar pisos dispo...
# 78664    monoambiente al frente - consultar pisos dispo...
# 78665    monoambiente al frente - consultar pisos dispo...
# 78666    monoambiente al frente - consultar pisos dispo...
# 78667    ubicacion privilegiada a metros del rio y del ...
# 78668    excelente propiedad con ladrillo al frente.  p...
# 78669    ubicacion privilegiada a metros del rio y del ...
# 78670    ubicacion privilegiada a metros del rio y del ...
# 78671    espectacular oportunidad!!! casa de 4 ambiente...
# 78672    vendo o permuto depto 3 amb. c\ cochera y c\ 2...
# 78673    casa en una planta ubicada en el barrio cerrad...
# Name: description, Length: 78674, dtype: object

# %%
#lista con todos los barrios posibles sin repetir (sin tildes y en minuscula)
barrios = properati_filtered[pd.notnull(properati_filtered['place_name'])].place_name
barrios = barrios.drop_duplicates(keep='first')
barrios = barrios.map(lambda b: eliminar_tildes(b).lower())
barrios.replace("capital federal", "sin barrio", inplace = True)
barrios
# Out:
# 0                                   sin barrio
# 1                                  san nicolas
# 2                                 constitucion
# 3                                    san telmo
# 4                                 barrio norte
# 5                                         boca
# 6                                        nunez
# 7                                     belgrano
# 8                                puerto madero
# 9                                     floresta
# 11                                     palermo
# 13                                    congreso
# 14                               san cristobal
# 16                                    recoleta
# 23                                   monserrat
# 24                                   caballito
# 32                                   balvanera
# 35                        centro / microcentro
# 45                                 las canitas
# 47                                villa crespo
# 50                               villa urquiza
# 51                                   mataderos
# 57                                      retiro
# 62                                    saavedra
# 67                                       boedo
# 71                                      flores
# 83                            parque patricios
# 96                                    paternal
# 97                                     almagro
# 98                                     coghlan
#                          ...
# 69065                         maquinista savio
# 69504                               el cazador
# 69548                          haras del sur i
# 69669                                  manzone
# 70712                   san diego country club
# 70761                                cuartel v
# 71216              barrio cerrado "springdale"
# 71305                               los alamos
# 71415                               terralagos
# 71507                           villa vatteone
# 71546          barrio cerrado "los alcanfores"
# 71893    barrio cerrado "altos de la horqueta"
# 72340                  barrio cerrado la masia
# 72690                           barrio el moro
# 73510                              san lorenzo
# 74525              barrio cerrado "villa rosa"
# 74697                           barrio melazzi
# 74908            barrio cerrado "isla del sol"
# 74977                           barrio marinas
# 75596                           william morris
# 75754              barrio privado los olivares
# 76001                                sourigues
# 76577                         villa monteagudo
# 76727                       medal country club
# 76803                            barrio vistas
# 76848               barrio cerrado "la merced"
# 76921           barrio cerrado "la candelaria"
# 77718              barrio cerrado "los condes"
# 77752            barrio cerrado "la rinconada"
# 78431       barrio cerrado el casco de alvarez
# Name: place_name, Length: 523, dtype: object

# %%
def asignar_barrio(d):
    for barrio in barrios:
        if(str(d.encode('utf-8')).find(barrio) >= 0):
              return barrio
    return "sin barrio"

# %%
sin_barrio = properati_filtered.loc[properati_filtered.place_name.str.contains("Capital Federal", na=False),:]
sin_barrio.place_name = sin_barrio.description.map(lambda d: asignar_barrio(d))
# Out:
# /home/jaz/fiuba/orga-de-datos-7506/lib/python2.7/site-packages/pandas/core/generic.py:2999: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
sin_barrio.place_name
# Out:
# 0               sin barrio
# 10              sin barrio
# 46              sin barrio
# 55              sin barrio
# 69              san isidro
# 77              sin barrio
# 79              sin barrio
# 125                  pilar
# 126             sin barrio
# 132             sin barrio
# 140             sin barrio
# 143             sin barrio
# 339                 flores
# 448                   once
# 449             sin barrio
# 746             sin barrio
# 751             sin barrio
# 752             sin barrio
# 754             sin barrio
# 755             sin barrio
# 756             sin barrio
# 768             sin barrio
# 769             sin barrio
# 777             sin barrio
# 793             sin barrio
# 794             sin barrio
# 795             sin barrio
# 797             sin barrio
# 809             sin barrio
# 813             sin barrio
#                ...
# 33868           sin barrio
# 34096           sin barrio
# 34098           sin barrio
# 34102           sin barrio
# 34103           sin barrio
# 34159           sin barrio
# 34249           sin barrio
# 34250           sin barrio
# 34251           sin barrio
# 34252           sin barrio
# 34253           sin barrio
# 34254           san isidro
# 34277           sin barrio
# 34283    parque avellaneda
# 34287    parque avellaneda
# 34288    parque avellaneda
# 34289    parque avellaneda
# 34290    parque avellaneda
# 34292    parque avellaneda
# 34293    parque avellaneda
# 34294    parque avellaneda
# 34300           sin barrio
# 34314         barrio norte
# 34318           sin barrio
# 34320    parque avellaneda
# 34321    parque avellaneda
# 34322    parque avellaneda
# 34323    parque avellaneda
# 34324    parque avellaneda
# 34325    parque avellaneda
# Name: place_name, Length: 1154, dtype: object

# %%
barrio_asignado = sin_barrio.loc[sin_barrio.place_name.str.contains("sin barrio", na=False) == False,:]
barrio_asignado.place_name
# Out:
# 69              san isidro
# 125                  pilar
# 339                 flores
# 448                   once
# 814               el talar
# 822         laguna del sol
# 1028              floresta
# 1084         puerto madero
# 1345              belgrano
# 1479                 tigre
# 1571              san juan
# 1572            san isidro
# 1689            san martin
# 1714      parque chacabuco
# 2475            san isidro
# 2487        barrio cerrado
# 2581            san isidro
# 2650               florida
# 2842            villa luro
# 3212            san martin
# 3968               liniers
# 4007               caseros
# 4037            san isidro
# 4038                 tigre
# 4061               florida
# 4062       general pacheco
# 4089               florida
# 4699                retiro
# 4703                 moron
# 4730        barrio cerrado
#                ...
# 32849              caseros
# 33006       barrio cerrado
# 33007           san isidro
# 33008                tigre
# 33158           san isidro
# 33304         monte grande
# 33422       barrio cerrado
# 33427             nordelta
# 33679                 once
# 33857              florida
# 33862              caseros
# 33865           san isidro
# 33866           san isidro
# 33867                tigre
# 34254           san isidro
# 34283    parque avellaneda
# 34287    parque avellaneda
# 34288    parque avellaneda
# 34289    parque avellaneda
# 34290    parque avellaneda
# 34292    parque avellaneda
# 34293    parque avellaneda
# 34294    parque avellaneda
# 34314         barrio norte
# 34320    parque avellaneda
# 34321    parque avellaneda
# 34322    parque avellaneda
# 34323    parque avellaneda
# 34324    parque avellaneda
# 34325    parque avellaneda
# Name: place_name, Length: 343, dtype: object

# %%
['country_name','created_on','currency','description',
       'expenses','extra','floor', 'geonames_id','id',
       'image_thumbnail', 'lat', 'lat-lon', 'lon', 'operation',
        'place_with_parent_names', 'price',
       'price_aprox_local_currency', 'price_aprox_usd', 'price_per_m2',
       'price_usd_per_m2', 'properati_url', 'property_type', 'rooms',
       'state_name', 'surface_covered_in_m2', 'surface_in_m2',
       'surface_total_in_m2','title']
# Out:
# array([u'country_name', u'created_on', u'currency', u'description',
#        u'expenses', u'extra', u'floor', u'geonames_id', u'id',
#        u'image_thumbnail', u'lat', u'lat-lon', u'lon', u'operation',
#        u'place_name', u'place_with_parent_names', u'price',
#        u'price_aprox_local_currency', u'price_aprox_usd', u'price_per_m2',
#        u'price_usd_per_m2', u'properati_url', u'property_type', u'rooms',
#        u'state_name', u'surface_covered_in_m2', u'surface_in_m2',
#        u'surface_total_in_m2', u'title'], dtype=object)

# %%
properati_barrios = pd.merge(properati_filtered, barrio_asignado,how='outer', on=['country_name','created_on','currency','description',
       'expenses','extra','floor', 'geonames_id','id',
       'image_thumbnail', 'lat', 'lat-lon', 'lon', 'operation',
        'place_with_parent_names', 'price',
       'price_aprox_local_currency', 'price_aprox_usd', 'price_per_m2',
       'price_usd_per_m2', 'properati_url', 'property_type', 'rooms',
       'state_name', 'surface_covered_in_m2', 'surface_in_m2',
       'surface_total_in_m2','title'])

# %%
ej_adivinado = properati_barrios.iloc[[69]]
print (ej_adivinado.place_name_x)
print (ej_adivinado.place_name_y)
# Out:
# 69    Capital Federal
# Name: place_name_x, dtype: object
# 69    san isidro
# Name: place_name_y, dtype: object

# %%
def get_place_name(data):
    places =[]
    for index, row in data.iterrows():
        if(pd.notnull(row['place_name_y'])):
            places.append(row['place_name_y'])
        else:
            places.append(row['place_name_x'])
    return places

# %%
properati_barrios['place_name']= get_place_name(properati_barrios)

# %%
ej = properati_barrios.iloc[[69]]
print(ej.place_name_x)
print(ej.place_name_y)
print(ej.place_name)
# Out:
# 69    Capital Federal
# Name: place_name_x, dtype: object
# 69    san isidro
# Name: place_name_y, dtype: object
# 69    san isidro
# Name: place_name, dtype: object

# %%
columnas = ['country_name','created_on','currency','description',
       'expenses','extra','floor', 'geonames_id','id',
       'image_thumbnail', 'lat', 'lat-lon', 'lon', 'operation',
       'place_name','place_with_parent_names', 'price',
       'price_aprox_local_currency', 'price_aprox_usd', 'price_per_m2',
       'price_usd_per_m2', 'properati_url', 'property_type', 'rooms',
       'state_name', 'surface_covered_in_m2', 'surface_in_m2',
       'surface_total_in_m2','title']
properati_barrios=properati_barrios.loc[:,columnas]

# %%
properati_barrios.to_csv("properati_filtered_barrios_adivinados.csv",encoding='utf-8',index=False)

# %%
properati_barrios.shape
# Out:
# (78674, 29)

# %%
# Out:
# (14166, 17)

# %%
columnas_no_price = ['id', 'created_on', 'property_type', 'operation',
       'place_with_parent_names', 'country_name', 'state_name',
       'lat-lon', 'lat', u'lon', 'surface_total_in_m2',
       'surface_covered_in_m2', 'floor', 'rooms', 'expenses',
       'description']
def adivinar_barrios_df_properati_sin_precios(df, nombre_csv):
    df.description = df.description.map(lambda d: unificate_description(d))
    sin_barrio = df.loc[properati_no_price.place_name.str.contains("Capital Federal", na=False),:]
    sin_barrio.place_name = sin_barrio.description.map(lambda d: asignar_barrio(d))
    barrio_asignado = sin_barrio.loc[sin_barrio.place_name.str.contains("sin barrio", na=False) == False,:]
    properati_barrios_no_price = pd.merge(df, barrio_asignado,how='outer', on=columnas_no_price)
    properati_barrios_no_price['place_name']= get_place_name(properati_barrios_no_price)
    columnas_no_price.append('place_name')
    properati_barrios_no_price=properati_barrios_no_price.loc[:,columnas_no_price]
    properati_barrios_no_price.to_csv(nombre_csv,encoding='utf-8',index=False)

# %%
properati_no_price = pd.read_csv('../tp1/properati_dataset_testing_noprice.csv',encoding='UTF-8')
adivinar_barrios_df_properati_sin_precios(properati_no_price, "properati_barrios_no_price.csv")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-f91fc5f90e79> in <module>()
#       1 properati_no_price = pd.read_csv('../tp1/properati_dataset_testing_noprice.csv',encoding='UTF-8')
# ----> 2 adivinar_barrios_df_properati_sin_precios(properati_no_price, "properati_barrios_no_price.csv")
#
# <ipython-input-53-5cf0bb066ffa> in adivinar_barrios_df_properati_sin_precios(df, nombre_csv)
#      11     properati_barrios_no_price = pd.merge(df, barrio_asignado,how='outer', on=columnas_no_price)
#      12     properati_barrios_no_price['place_name']= get_place_name(properati_barrios_no_price)
# ---> 13     properati_barrios_no_price=properati_barrios_no_price.loc[:,columnas_no_price.append('place_name')]
#      14     properati_barrios_no_price.to_csv(nombre_csv,encoding='utf-8',index=False)
#
# /home/jaz/fiuba/orga-de-datos-7506/lib/python2.7/site-packages/pandas/core/indexing.pyc in __getitem__(self, key)
#    1323             except (KeyError, IndexError):
#    1324                 pass
# -> 1325             return self._getitem_tuple(key)
#    1326         else:
#    1327             key = com._apply_if_callable(key, self.obj)
#
# /home/jaz/fiuba/orga-de-datos-7506/lib/python2.7/site-packages/pandas/core/indexing.pyc in _getitem_tuple(self, tup)
#     834     def _getitem_tuple(self, tup):
#     835         try:
# --> 836             return self._getitem_lowerdim(tup)
#     837         except IndexingError:
#     838             pass
#
# /home/jaz/fiuba/orga-de-datos-7506/lib/python2.7/site-packages/pandas/core/indexing.pyc in _getitem_lowerdim(self, tup)
#     965         for i, key in enumerate(tup):
#     966             if is_label_like(key) or isinstance(key, tuple):
# --> 967                 section = self._getitem_axis(key, axis=i)
#     968
#     969                 # we have yielded a scalar ?
#
# /home/jaz/fiuba/orga-de-datos-7506/lib/python2.7/site-packages/pandas/core/indexing.pyc in _getitem_axis(self, key, axis)
#    1549
#    1550         # fall thru to straight lookup
# -> 1551         self._has_valid_type(key, axis)
#    1552         return self._get_label(key, axis=axis)
#    1553
#
# /home/jaz/fiuba/orga-de-datos-7506/lib/python2.7/site-packages/pandas/core/indexing.pyc in _has_valid_type(self, key, axis)
#    1432                 key = self._convert_scalar_indexer(key, axis)
#    1433                 if not ax.contains(key):
# -> 1434                     error()
#    1435             except TypeError as e:
#    1436
#
# /home/jaz/fiuba/orga-de-datos-7506/lib/python2.7/site-packages/pandas/core/indexing.pyc in error()
#    1424             def error():
#    1425                 if isnull(key):
# -> 1426                     raise TypeError("cannot use label indexing with a null "
#    1427                                     "key")
#    1428                 raise KeyError("the label [%s] is not in the [%s]" %
#
# TypeError: cannot use label indexing with a null key

# %%
#verificar
properati_barrios_no_price = pd.read_csv('../tp1/properati_barrios_no_price.csv',encoding='UTF-8')

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-52-87c614ea38df> in <module>()
# ----> 1 properati_barrios_no_price.place_name
#
# /home/jaz/fiuba/orga-de-datos-7506/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    2968             if name in self._info_axis:
#    2969                 return self[name]
# -> 2970             return object.__getattribute__(self, name)
#    2971
#    2972     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'place_name'

# %%
properati_no_price.shape
# Out:
# (14166, 17)

# %%
properati_barrios_no_price.loc[pd.notnull(properati_barrios_no_price.place_name_y),:]
# Out:
#             id  created_on property_type operation     place_name_x  \
# 70     2264183  2017-08-01  departamento     venta  Capital Federal
# 74     2264206  2017-08-01  departamento     venta  Capital Federal
# 75     2264212  2017-08-01  departamento     venta  Capital Federal
# 76     2264215  2017-08-01  departamento     venta  Capital Federal
# 77     2264218  2017-08-01  departamento     venta  Capital Federal
# 79     2264221  2017-08-01  departamento     venta  Capital Federal
# 80     2264227  2017-08-01  departamento     venta  Capital Federal
# 82     2264234  2017-08-01  departamento     venta  Capital Federal
# 88     2264265  2017-08-01  departamento     venta  Capital Federal
# 106    2264482  2017-08-01  departamento     venta  Capital Federal
# 125    2264598  2017-08-01  departamento     venta  Capital Federal
# 126    2264600  2017-08-01  departamento     venta  Capital Federal
# 127    2264603  2017-08-01  departamento     venta  Capital Federal
# 128    2264604  2017-08-01  departamento     venta  Capital Federal
# 129    2264607  2017-08-01  departamento     venta  Capital Federal
# 130    2264610  2017-08-01  departamento     venta  Capital Federal
# 135    2264633  2017-08-01            ph     venta  Capital Federal
# 230    2265183  2017-08-01  departamento     venta  Capital Federal
# 428    2266079  2017-08-01          casa     venta  Capital Federal
# 429    2266080  2017-08-01          casa     venta  Capital Federal
# 430    2266083  2017-08-01          casa     venta  Capital Federal
# 431    2266084  2017-08-01          casa     venta  Capital Federal
# 433    2266105  2017-08-01          casa     venta  Capital Federal
# 434    2266106  2017-08-01          casa     venta  Capital Federal
# 435    2266109  2017-08-01          casa     venta  Capital Federal
# 436    2266110  2017-08-01          casa     venta  Capital Federal
# 437    2266113  2017-08-01          casa     venta  Capital Federal
# 438    2266114  2017-08-01          casa     venta  Capital Federal
# 439    2266117  2017-08-01          casa     venta  Capital Federal
# 440    2266118  2017-08-01          casa     venta  Capital Federal
# ...        ...         ...           ...       ...              ...
# 12266  2197580  2017-08-01          casa     venta  Capital Federal
# 12376  2214587  2017-08-01          casa     venta  Capital Federal
# 12377  2214588  2017-08-01          casa     venta  Capital Federal
# 12378  2214589  2017-08-01          casa     venta  Capital Federal
# 12382  2214595  2017-08-01          casa     venta  Capital Federal
# 12524  2218316  2017-08-01          casa     venta  Capital Federal
# 12575  2219555  2017-08-01          casa     venta  Capital Federal
# 12684  2221966  2017-08-17  departamento     venta  Capital Federal
# 12687  2221976  2017-08-17          casa     venta  Capital Federal
# 12728  2223813  2017-08-01          casa     venta  Capital Federal
# 12729  2223814  2017-08-01          casa     venta  Capital Federal
# 12816  2225110  2017-08-01          casa     venta  Capital Federal
# 12817  2225111  2017-08-01          casa     venta  Capital Federal
# 12818  2225115  2017-08-01          casa     venta  Capital Federal
# 12819  2225130  2017-08-01          casa     venta  Capital Federal
# 12824  2225138  2017-08-01          casa     venta  Capital Federal
# 13151  2228452  2017-08-01  departamento     venta  Capital Federal
# 13211  2230193  2017-08-01          casa     venta  Capital Federal
# 13212  2230194  2017-08-01          casa     venta  Capital Federal
# 13213  2230198  2017-08-01          casa     venta  Capital Federal
# 13385  2232983  2017-08-11            ph     venta  Capital Federal
# 13696  2236872  2017-08-23  departamento     venta  Capital Federal
# 13866  2241006  2017-08-18  departamento     venta  Capital Federal
# 13911  2241871  2017-08-01          casa     venta  Capital Federal
# 13912  2241875  2017-08-01          casa     venta  Capital Federal
# 13913  2241876  2017-08-01          casa     venta  Capital Federal
# 13915  2241884  2017-08-01          casa     venta  Capital Federal
# 13962  2242134  2017-08-24          casa     venta  Capital Federal
# 14067  2244357  2017-08-01          casa     venta  Capital Federal
# 14068  2244358  2017-08-01          casa     venta  Capital Federal
#
#            place_with_parent_names country_name       state_name  \
# 70     |Argentina|Capital Federal|    Argentina  Capital Federal
# 74     |Argentina|Capital Federal|    Argentina  Capital Federal
# 75     |Argentina|Capital Federal|    Argentina  Capital Federal
# 76     |Argentina|Capital Federal|    Argentina  Capital Federal
# 77     |Argentina|Capital Federal|    Argentina  Capital Federal
# 79     |Argentina|Capital Federal|    Argentina  Capital Federal
# 80     |Argentina|Capital Federal|    Argentina  Capital Federal
# 82     |Argentina|Capital Federal|    Argentina  Capital Federal
# 88     |Argentina|Capital Federal|    Argentina  Capital Federal
# 106    |Argentina|Capital Federal|    Argentina  Capital Federal
# 125    |Argentina|Capital Federal|    Argentina  Capital Federal
# 126    |Argentina|Capital Federal|    Argentina  Capital Federal
# 127    |Argentina|Capital Federal|    Argentina  Capital Federal
# 128    |Argentina|Capital Federal|    Argentina  Capital Federal
# 129    |Argentina|Capital Federal|    Argentina  Capital Federal
# 130    |Argentina|Capital Federal|    Argentina  Capital Federal
# 135    |Argentina|Capital Federal|    Argentina  Capital Federal
# 230    |Argentina|Capital Federal|    Argentina  Capital Federal
# 428    |Argentina|Capital Federal|    Argentina  Capital Federal
# 429    |Argentina|Capital Federal|    Argentina  Capital Federal
# 430    |Argentina|Capital Federal|    Argentina  Capital Federal
# 431    |Argentina|Capital Federal|    Argentina  Capital Federal
# 433    |Argentina|Capital Federal|    Argentina  Capital Federal
# 434    |Argentina|Capital Federal|    Argentina  Capital Federal
# 435    |Argentina|Capital Federal|    Argentina  Capital Federal
# 436    |Argentina|Capital Federal|    Argentina  Capital Federal
# 437    |Argentina|Capital Federal|    Argentina  Capital Federal
# 438    |Argentina|Capital Federal|    Argentina  Capital Federal
# 439    |Argentina|Capital Federal|    Argentina  Capital Federal
# 440    |Argentina|Capital Federal|    Argentina  Capital Federal
# ...                            ...          ...              ...
# 12266  |Argentina|Capital Federal|    Argentina  Capital Federal
# 12376  |Argentina|Capital Federal|    Argentina  Capital Federal
# 12377  |Argentina|Capital Federal|    Argentina  Capital Federal
# 12378  |Argentina|Capital Federal|    Argentina  Capital Federal
# 12382  |Argentina|Capital Federal|    Argentina  Capital Federal
# 12524  |Argentina|Capital Federal|    Argentina  Capital Federal
# 12575  |Argentina|Capital Federal|    Argentina  Capital Federal
# 12684  |Argentina|Capital Federal|    Argentina  Capital Federal
# 12687  |Argentina|Capital Federal|    Argentina  Capital Federal
# 12728  |Argentina|Capital Federal|    Argentina  Capital Federal
# 12729  |Argentina|Capital Federal|    Argentina  Capital Federal
# 12816  |Argentina|Capital Federal|    Argentina  Capital Federal
# 12817  |Argentina|Capital Federal|    Argentina  Capital Federal
# 12818  |Argentina|Capital Federal|    Argentina  Capital Federal
# 12819  |Argentina|Capital Federal|    Argentina  Capital Federal
# 12824  |Argentina|Capital Federal|    Argentina  Capital Federal
# 13151  |Argentina|Capital Federal|    Argentina  Capital Federal
# 13211  |Argentina|Capital Federal|    Argentina  Capital Federal
# 13212  |Argentina|Capital Federal|    Argentina  Capital Federal
# 13213  |Argentina|Capital Federal|    Argentina  Capital Federal
# 13385  |Argentina|Capital Federal|    Argentina  Capital Federal
# 13696  |Argentina|Capital Federal|    Argentina  Capital Federal
# 13866  |Argentina|Capital Federal|    Argentina  Capital Federal
# 13911  |Argentina|Capital Federal|    Argentina  Capital Federal
# 13912  |Argentina|Capital Federal|    Argentina  Capital Federal
# 13913  |Argentina|Capital Federal|    Argentina  Capital Federal
# 13915  |Argentina|Capital Federal|    Argentina  Capital Federal
# 13962  |Argentina|Capital Federal|    Argentina  Capital Federal
# 14067  |Argentina|Capital Federal|    Argentina  Capital Federal
# 14068  |Argentina|Capital Federal|    Argentina  Capital Federal
#
#                              lat-lon        lat        lon  \
# 70                               NaN        NaN        NaN
# 74                               NaN        NaN        NaN
# 75                               NaN        NaN        NaN
# 76                               NaN        NaN        NaN
# 77                               NaN        NaN        NaN
# 79                               NaN        NaN        NaN
# 80                               NaN        NaN        NaN
# 82                               NaN        NaN        NaN
# 88                               NaN        NaN        NaN
# 106                              NaN        NaN        NaN
# 125                              NaN        NaN        NaN
# 126                              NaN        NaN        NaN
# 127                              NaN        NaN        NaN
# 128                              NaN        NaN        NaN
# 129                              NaN        NaN        NaN
# 130                              NaN        NaN        NaN
# 135                              NaN        NaN        NaN
# 230           -34.5865889,-58.441458 -34.586589 -58.441458
# 428                              NaN        NaN        NaN
# 429                              NaN        NaN        NaN
# 430                              NaN        NaN        NaN
# 431                              NaN        NaN        NaN
# 433                              NaN        NaN        NaN
# 434                              NaN        NaN        NaN
# 435                              NaN        NaN        NaN
# 436                              NaN        NaN        NaN
# 437                              NaN        NaN        NaN
# 438                              NaN        NaN        NaN
# 439                              NaN        NaN        NaN
# 440                              NaN        NaN        NaN
# ...                              ...        ...        ...
# 12266                            NaN        NaN        NaN
# 12376                            NaN        NaN        NaN
# 12377                            NaN        NaN        NaN
# 12378                            NaN        NaN        NaN
# 12382                            NaN        NaN        NaN
# 12524                            NaN        NaN        NaN
# 12575        -34.5825969,-58.4889016 -34.582597 -58.488902
# 12684  -34.6324047584,-58.4538283757 -34.632405 -58.453828
# 12687                            NaN        NaN        NaN
# 12728                            NaN        NaN        NaN
# 12729                            NaN        NaN        NaN
# 12816        -34.6788321,-58.4679273 -34.678832 -58.467927
# 12817        -34.6788321,-58.4679273 -34.678832 -58.467927
# 12818                            NaN        NaN        NaN
# 12819        -34.6788321,-58.4679273 -34.678832 -58.467927
# 12824        -34.6788321,-58.4679273 -34.678832 -58.467927
# 13151                            NaN        NaN        NaN
# 13211                            NaN        NaN        NaN
# 13212                            NaN        NaN        NaN
# 13213                            NaN        NaN        NaN
# 13385  -34.6426608733,-58.4735624847 -34.642661 -58.473562
# 13696   -34.604807855,-58.4710709383 -34.604808 -58.471071
# 13866                            NaN        NaN        NaN
# 13911                            NaN        NaN        NaN
# 13912                            NaN        NaN        NaN
# 13913                            NaN        NaN        NaN
# 13915                            NaN        NaN        NaN
# 13962                            NaN        NaN        NaN
# 14067                            NaN        NaN        NaN
# 14068                            NaN        NaN        NaN
#
#        surface_total_in_m2  surface_covered_in_m2  floor  rooms expenses  \
# 70                    62.0                   59.0    NaN    NaN      NaN
# 74                    62.0                   59.0    NaN    NaN      NaN
# 75                    62.0                   59.0    NaN    NaN      NaN
# 76                    62.0                   59.0    NaN    NaN      NaN
# 77                    62.0                   59.0    NaN    NaN      NaN
# 79                    62.0                   59.0    NaN    NaN      NaN
# 80                    94.0                   68.0    NaN    NaN      NaN
# 82                   117.0                   91.0    NaN    NaN      NaN
# 88                   115.0                   62.0    NaN    NaN      NaN
# 106                   77.0                   77.0    NaN    NaN     3500
# 125                   62.0                   59.0    NaN    NaN      NaN
# 126                   62.0                   59.0    NaN    NaN      NaN
# 127                   62.0                   59.0    NaN    NaN      NaN
# 128                   62.0                   59.0    NaN    NaN      NaN
# 129                   62.0                   59.0    NaN    NaN      NaN
# 130                   62.0                   59.0    NaN    NaN      NaN
# 135                   85.0                   50.0    NaN    NaN      NaN
# 230                   64.0                   60.0    NaN    2.0     2000
# 428                    NaN                  320.0    NaN    NaN      NaN
# 429                    NaN                  320.0    NaN    NaN      NaN
# 430                    NaN                  526.0    NaN    NaN      NaN
# 431                    NaN                  526.0    NaN    NaN      NaN
# 433                    NaN                  300.0    NaN    NaN      NaN
# 434                    NaN                  300.0    NaN    NaN      NaN
# 435                    NaN                  350.0    NaN    NaN      NaN
# 436                    NaN                  350.0    NaN    NaN      NaN
# 437                    NaN                  203.0    NaN    NaN      NaN
# 438                    NaN                  203.0    NaN    NaN      NaN
# 439                    NaN                  203.0    NaN    NaN      NaN
# 440                    NaN                  203.0    NaN    NaN      NaN
# ...                    ...                    ...    ...    ...      ...
# 12266                  NaN                   80.0    NaN    NaN      NaN
# 12376                  NaN                  150.0    NaN    NaN      NaN
# 12377                  NaN                  150.0    NaN    NaN      NaN
# 12378                  NaN                  203.0    NaN    NaN      NaN
# 12382                  NaN                  150.0    NaN    NaN      NaN
# 12524                  NaN                  285.0    NaN    NaN      NaN
# 12575                  NaN                  210.0    NaN    NaN      NaN
# 12684                  NaN                   63.0    NaN    NaN      500
# 12687                133.0                  113.0    NaN    NaN      NaN
# 12728                  NaN                  220.0    NaN    NaN      NaN
# 12729                  NaN                  220.0    NaN    NaN      NaN
# 12816                  NaN                  317.0    NaN    NaN      NaN
# 12817                  NaN                  317.0    NaN    NaN      NaN
# 12818                  NaN                  166.0    NaN    NaN      NaN
# 12819                  NaN                  317.0    NaN    NaN      NaN
# 12824                  NaN                  203.0    NaN    NaN      NaN
# 13151                160.0                   65.0    NaN    NaN     2100
# 13211                  NaN                  190.0    NaN    NaN      NaN
# 13212                  NaN                  360.0    NaN    NaN      NaN
# 13213                  NaN                  140.0    NaN    NaN      NaN
# 13385                  NaN                   70.0    NaN    NaN      NaN
# 13696                  NaN                    NaN    NaN    NaN     1800
# 13866                  NaN                  192.0    NaN    6.0      NaN
# 13911                  NaN                  427.0    NaN    NaN      NaN
# 13912                245.0                  245.0    NaN    NaN      NaN
# 13913                245.0                  245.0    NaN    NaN      NaN
# 13915                200.0                  145.0    NaN    NaN      NaN
# 13962                  NaN                  140.0    NaN    NaN      NaN
# 14067                  NaN                  286.0    NaN    NaN      NaN
# 14068                  NaN                  286.0    NaN    NaN      NaN
#
#                                              description       place_name_y  \
# 70     departamentos semipisos en venta de 3 ambiente...  parque avellaneda
# 74     departamentos semipisos en venta de 3 ambiente...  parque avellaneda
# 75     departamentos semipisos en venta de 3 ambiente...  parque avellaneda
# 76     departamentos semipisos en venta de 3 ambiente...  parque avellaneda
# 77     departamentos semipisos en venta de 3 ambiente...  parque avellaneda
# 79     departamentos semipisos en venta de 3 ambiente...  parque avellaneda
# 80     departamento piso en venta de 3 ambientes en p...  parque avellaneda
# 82     departamento piso en venta de 4 ambientes en p...  parque avellaneda
# 88     departamentos semipisos en venta de 3 ambiente...  parque avellaneda
# 106    departamento de 77 m2 apto profesional. edific...       barrio norte
# 125    departamentos semipisos en venta de 3 ambiente...  parque avellaneda
# 126    departamentos semipisos en venta de 3 ambiente...  parque avellaneda
# 127    departamentos semipisos en venta de 3 ambiente...  parque avellaneda
# 128    departamentos semipisos en venta de 3 ambiente...  parque avellaneda
# 129    departamentos semipisos en venta de 3 ambiente...  parque avellaneda
# 130    departamentos semipisos en venta de 3 ambiente...  parque avellaneda
# 135     excelente ph de 2 ambientes + habitacion en a...  parque avellaneda
# 230    departamento en duplex de 2 ambientes en venta...            palermo
# 428    muy buena casa en excelente estado, con 4 dorm...         san isidro
# 429    muy buena casa en excelente estado, con 4 dorm...         san isidro
# 430    excelente casa, con el mejor lote, en el mejor...             rincon
# 431    excelente casa, con el mejor lote, en el mejor...             rincon
# 433    * casa con espectacular vista a laguna - siste...         san isidro
# 434    * casa con espectacular vista a laguna - siste...         san isidro
# 435    excelente chalet en dos plantas en barrio con ...               once
# 436    excelente chalet en dos plantas en barrio con ...               once
# 437    * muy linda casa en lote interno - excelente u...         san isidro
# 438    * muy linda casa en lote interno - excelente u...         san isidro
# 439    * venta con renta - hasta enero 2019.* muy lin...         san isidro
# 440    * venta con renta - hasta enero 2019.* muy lin...         san isidro
# ...                                                  ...                ...
# 12266  etapa iii - manzana 8 - lote 34 (entrega progr...           nordelta
# 12376  * casa con vista a la laguna de san gabriel - ...         san isidro
# 12377  * casa con vista a la laguna de san gabriel - ...         san isidro
# 12378  * casa sobre lote interno en isla.- superficie...         san isidro
# 12382  * casa con vista a la laguna de san gabriel - ...           nordelta
# 12524  importantes casa y lote (entre los 10 lotes co...       don torcuato
# 12575  barrio cerrado "las  glorias" en el km. 40 de ...           nordelta
# 12684  muy buen depto de 4 amb. o 3 amb. con escritor...             flores
# 12687  villa del parque - triplex en venta de 3 ambie...   villa del parque
# 12728  muy buena casa en lote central. hall de entrad...         san isidro
# 12729  muy buena casa en lote central. hall de entrad...         san isidro
# 12816  * casa sobre laguna chica proxima a house ppal...         san isidro
# 12817  * casa sobre laguna chica proxima a house ppal...         san isidro
# 12818  * lindisima casa moderna a la laguna, frente a...              pilar
# 12819  venta con renta - alquilada hasta marzo 2017* ...           nordelta
# 12824  venta con renta - alquilada hasta enero 2019mu...           nordelta
# 13151  departamento 3 ambientes en parque chacabuco e...   parque chacabuco
# 13211  * excelente casa sobre lote interno (calle a c...         san isidro
# 13212  muy buena casa , de estudio donaldson !!! hall...         san isidro
# 13213  * el canton - "barrio norte" - lote interno - ...       barrio norte
# 13385  excelente ph 3 ambientes lateral totalmente de...  parque avellaneda
# 13696  excelente y super luminoso depto de 3 ambiente...         san martin
# 13866  en el corazon de villa devoto y a mts. de plaz...       villa devoto
# 13911  muy buena casa en calle cortada con seguridad ...         san isidro
# 13912  en pleno corazon de la horqueta, sobre lote de...         san isidro
# 13913  en pleno corazon de la horqueta, sobre lote de...         san isidro
# 13915  * casa a la laguna cercano de puerta principal...       barrio norte
# 13962  * el canton - "barrio norte" - lote interno - ...       barrio norte
# 14067  * excelente casa y ubicacion - "a laguna" - ce...         san isidro
# 14068  * excelente casa y ubicacion - "a laguna" - ce...         san isidro
#
#               place_name
# 70     parque avellaneda
# 74     parque avellaneda
# 75     parque avellaneda
# 76     parque avellaneda
# 77     parque avellaneda
# 79     parque avellaneda
# 80     parque avellaneda
# 82     parque avellaneda
# 88     parque avellaneda
# 106         barrio norte
# 125    parque avellaneda
# 126    parque avellaneda
# 127    parque avellaneda
# 128    parque avellaneda
# 129    parque avellaneda
# 130    parque avellaneda
# 135    parque avellaneda
# 230              palermo
# 428           san isidro
# 429           san isidro
# 430               rincon
# 431               rincon
# 433           san isidro
# 434           san isidro
# 435                 once
# 436                 once
# 437           san isidro
# 438           san isidro
# 439           san isidro
# 440           san isidro
# ...                  ...
# 12266           nordelta
# 12376         san isidro
# 12377         san isidro
# 12378         san isidro
# 12382           nordelta
# 12524       don torcuato
# 12575           nordelta
# 12684             flores
# 12687   villa del parque
# 12728         san isidro
# 12729         san isidro
# 12816         san isidro
# 12817         san isidro
# 12818              pilar
# 12819           nordelta
# 12824           nordelta
# 13151   parque chacabuco
# 13211         san isidro
# 13212         san isidro
# 13213       barrio norte
# 13385  parque avellaneda
# 13696         san martin
# 13866       villa devoto
# 13911         san isidro
# 13912         san isidro
# 13913         san isidro
# 13915       barrio norte
# 13962       barrio norte
# 14067         san isidro
# 14068         san isidro
#
# [152 rows x 19 columns]
