# %%
import pandas as pd
import numpy as np
from pandas import Series

# %%
import random

# %%
import pyspark_csv as pycsv
from pyspark import SparkContext 
sc = SparkContext.getOrCreate()
from pyspark.sql import SQLContext
sqlContext = SQLContext(sc)

# %% [markdown]
# # Distancias

# %%
def get_minkowsky_distance(p):

    def minkowsky_distance(v1, v2):
        if(len(v1) != len(v2)):
            raise ValueError("The vectors do not have the same dimention")
        s = 0
        for i in range(len(v1)):
            s += abs((v1[i]-v2[i])**p)
        if(p == 0): return s
        return round((s)**(1.0/p),2)
    return minkowsky_distance

hamming = get_minkowsky_distance(0)
manhattan = get_minkowsky_distance(1)
euclidean = get_minkowsky_distance(2)

# %%
df= pd.read_csv('../tp1/data_filled_ready_to_train.csv',encoding='UTF-8')

# %%
def split_train_test_sets(df, porcentage):
    indices = random.sample(df.index, (int)(df.shape[0]*porcentage))
    return df.drop(indices),df.iloc[indices]

# %%
train, test = split_train_test_sets(df, 0.33)
test = test.loc[:,['created_on','property_type','lat','lon', 'place_name',
       'state_name', 'surface_total_in_m2', 'surface_covered_in_m2',
       'description', 'floor', 'rooms', 'expenses']]

# %%
#esto tarda
X_train_rdd = sqlContext.createDataFrame(train).rdd
X_test_rdd = sqlContext.createDataFrame(test).rdd

# %%
X_train_rdd.take(1)
# Out:
# [Row(created_on=94953600.0, property_type=1, lat=-34.6037137392, lon=-58.3815808896, place_name=430, state_name=3, surface_total_in_m2=52.0, surface_covered_in_m2=52.0, description=20, floor=1.0, rooms=1.0, expenses=10.0, price_aprox_usd=125000.0, price_usd_per_m2=2403.84615385)]

# %%
def get_X()

def get_nearest_neighbors(x, X_train_rdd):
    X_train_rdd.map(lambda neighbor: (neighbor,euclidean(x,neighbor))).sortBy(lambda (neighbor,distance): distance)

# %%
nn = X_test_rdd.map(lambda x: get_nearest_neighbors(x,X_train_rdd))

# %% [markdown]
# # USANDO LA LIBRERIA

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LinearRegression

# %%
(max(df.price_usd_per_m2)-min(df.price_usd_per_m2))/1000
# Out:
# 3.8339906286570002

# %%
min(df.price_usd_per_m2)
# Out:
# 226.923076923

# %%
int((3000.89-226)/4)
# Out:
# 693

# %%
df= pd.read_csv('../tp1/data_filled_ready_to_train.csv',encoding='UTF-8')
df['bin'] = df.price_usd_per_m2.map(lambda value: int((value-226)/50) )

# %%
X = df.loc[:,['created_on','property_type','lat','lon', 'place_name',
       'state_name', 'surface_total_in_m2', 'surface_covered_in_m2',
       'description', 'floor', 'rooms', 'expenses']]
y = df.bin
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.10, random_state=42)

# %%
neigh = KNeighborsClassifier(n_neighbors=3)
neigh.fit(X_train, y_train) 
predictions = neigh.predict(X_test)

# %%
# el error cuadratico medio
print("Mean squared error: %.2f" % mean_squared_error(y_test, predictions))
# Out:
# Mean squared error: 272.07

# %%
porcent =100*abs((predictions-y_test))/y_test
porcent.mean()
# Out:
# inf

# %%
df_to_predict= pd.read_csv('../tp1/data_filled_ready_to_predict.csv',encoding='UTF-8')

# %%
neigh = KNeighborsClassifier(n_neighbors=3)
neigh.fit(X.loc[:,['lat','lon']],  df['bin']) 
predictions = neigh.predict(df_to_predict.loc[:,['lat','lon']])

# %%
df_to_predict['bin'] = predictions
properati_no_price= pd.read_csv('../tp1/properati_dataset_testing_noprice.csv',encoding='UTF-8')
df_to_predict['id']=properati_no_price.id

# %%
def predecir(df_to_predict, X_train, y_train):
    regr = LinearRegression()
    regr.fit(X_train, y_train)
    y_price_usd_predicted = regr.predict(df_to_predict)
    return y_price_usd_predicted

# %%
columns = ['created_on','property_type','lat','lon', 'place_name',
       'state_name', 'surface_total_in_m2', 'surface_covered_in_m2',
       'description', 'floor', 'rooms', 'expenses']

bins =df['bin'].drop_duplicates(keep='first')


df_predictions_list= []
for b in bins:
    print b
    df_bin = df_to_predict.loc[df_to_predict.bin == b,columns]
    x = df.loc[df.bin == b,:]
    df_predictions_list.append(predecir(df_bin, x.loc[:,columns], x.price_aprox_usd) )
# Out:
# 3
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-252-6a3d6fca50e7> in <module>()
#      10     print b
#      11     df_bin = df_to_predict.loc[df_to_predict.bin == b,columns]
# ---> 12     df_predictions_list.append(predecir(df_bin, x.loc[:,columns], x.price_aprox_usd) )
#
# NameError: name 'x' is not defined

# %%
df_to_predict['price_predicted'] = df_to_predict['price_m2_predicted'] * df_to_predict['surface_total_in_m2']
df_to_predict['price_predicted'] = df_to_predict['price_predicted'].map(lambda v: int(v))

# %%
properati_no_price= pd.read_csv('../tp1/properati_dataset_testing_noprice.csv',encoding='UTF-8')
pd.concat([properati_no_price.id,df_to_predict], axis=1)
# Out:
#             id   created_on  property_type  place_name  state_name        lat  \
# 0         3632  146534400.0              1         152           4 -34.610988
# 1         3633  146620800.0              1          29           3   0.000000
# 2      2263404  144547200.0              1         136           4 -34.589363
# 3      2263405  144547200.0              1          40           4 -34.584099
# 4      2263406  144547200.0              1          40           4 -34.584099
# 5      2263407  144547200.0              1          40           4 -34.584099
# 6      2263408  144547200.0              1          40           4 -34.584099
# 7      2263409  144547200.0              1          40           4 -34.584099
# 8      2263410  144547200.0              1          47           4 -34.578721
# 9      2263411  144547200.0              1           7           4 -34.608672
# 10     2263412  144547200.0              1           7           4 -34.608672
# 11     2263413  144547200.0              1           7           4 -34.608672
# 12     2263415  144547200.0              1         152           4 -34.612369
# 13     2263416  144547200.0              1          20           4 -34.562211
# 14     2263417  144547200.0              1         196           4 -34.598553
# 15     2263418  144547200.0              1         196           4 -34.598553
# 16     2263419  144547200.0              1         196           4 -34.598553
# 17     2263420  144547200.0              1         196           4 -34.598553
# 18     2263421  144547200.0              1         196           4 -34.598553
# 19     2263422  144547200.0              1         196           4 -34.598553
# 20     2263423  144547200.0              1         196           4 -34.598553
# 21     2263424  144547200.0              1         196           4 -34.598553
# 22     2263425  144547200.0              1         196           4 -34.598553
# 23     2263426  144547200.0              1         196           4 -34.598553
# 24     2263427  144547200.0              1         196           4 -34.598553
# 25     2263428  144547200.0              1         196           4 -34.598553
# 26     2263429  144547200.0              1         196           4 -34.598553
